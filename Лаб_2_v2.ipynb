# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# Задача 1. Верификация моментов процесса CIR

# %%
kappa = 2.0
theta = 1.0
sigma = 0.3
X0 = 1.5
T = 2.0
dt = 0.001
M = 1000  # Количество траекторий
N = int(T / dt)
t = np.linspace(0, T, N + 1)

# Симуляция CIR (схема Эйлера-Маруямы с усечением для положительности)
def simulate_cir(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    t = np.linspace(0, T, N + 1)
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    
    for i in range(N):
        dX = kappa * (theta - X[:, i]) * dt + sigma * np.sqrt(np.maximum(X[:, i], 0)) * dW[:, i]
        X[:, i + 1] = X[:, i] + dX
        # Усечение для избежания отрицательных значений (полная схема усечения)
        X[:, i + 1] = np.maximum(X[:, i + 1], 0)
    return t, X

t, X_paths = simulate_cir(M, N, T, X0, kappa, theta, sigma)

# Теоретические моменты в момент T
E_X_T = theta + (X0 - theta) * np.exp(-kappa * T)
Var_X_T = (sigma**2 / (2 * kappa)) * theta * (1 - np.exp(-kappa * T))**2 + \
          X0 * (sigma**2 / kappa) * np.exp(-kappa * T) * (1 - np.exp(-kappa * T))
E_X2_T = Var_X_T + E_X_T**2

# Выборочные моменты
sample_mean = np.mean(X_paths[:, -1])
sample_var = np.var(X_paths[:, -1])
sample_moment2 = np.mean(X_paths[:, -1]**2)

print(f"Задача 1: Верификация моментов CIR")
print(f"Теоретическое E[X(T)]: {E_X_T:.4f}, Выборочное: {sample_mean:.4f}")
print(f"Теоретическое E[X^2(T)]: {E_X2_T:.4f}, Выборочное: {sample_moment2:.4f}")
print(f"Теоретическая Var(X(T)): {Var_X_T:.4f}, Выборочная: {sample_var:.4f}")
# Out:
# Задача 1: Верификация моментов CIR
# Теоретическое E[X(T)]: 1.0092, Выборочное: 1.0148
# Теоретическое E[X^2(T)]: 1.0413, Выборочное: 1.0510
# Теоретическая Var(X(T)): 0.0229, Выборочная: 0.0211

# %% [markdown]
# Задача 2. Свойства модели Блэка-Шоулза-Мертона

# %%
theta1 = 0.16  # Процентная ставка
theta2 = 0.30  # Волатильность
X0 = 1.0
T = 1.0
dt = 0.001
N = int(T / dt)
M = 1000

# Симуляция BSM
def simulate_bsm(M, N, T, X0, mu, sigma):
    dt = T / N
    t = np.linspace(0, T, N + 1)
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    
    for i in range(N):
        dX = mu * X[:, i] * dt + sigma * X[:, i] * dW[:, i]
        X[:, i + 1] = X[:, i] + dX
    return t, X

t, X_paths_bsm = simulate_bsm(M, N, T, X0, theta1, theta2)

# Лог-доходности
log_returns = np.log(X_paths_bsm[:, -1] / X0)

# Теоретические параметры для лог-доходностей
mu_log = (theta1 - 0.5 * theta2**2) * T
sigma_log = theta2 * np.sqrt(T)

plt.figure(figsize=(10, 6))
plt.hist(log_returns, bins=50, density=True, alpha=0.6, label='Симуляция')
x = np.linspace(min(log_returns), max(log_returns), 100)
plt.plot(x, norm.pdf(x, mu_log, sigma_log), 'r-', label='Теория N(mu, sigma^2)')
plt.title('Гистограмма лог-доходностей vs Теоретическое распределение')
plt.xlabel('log(X_T / X_0)')
plt.ylabel('Плотность')
plt.legend()
plt.grid(True)
plt.show()

print(f"Задача 2: Теоретическое среднее лог-доходности: {mu_log:.4f}, Выборочное: {np.mean(log_returns):.4f}")
print(f"Теоретическая дисперсия лог-доходности: {sigma_log**2:.4f}, Выборочная: {np.var(log_returns):.4f}")
# Out:
# Задача 2: Теоретическое среднее лог-доходности: 0.1150, Выборочное: 0.1188
# Теоретическая дисперсия лог-доходности: 0.0900, Выборочная: 0.0923

# %% [markdown]
# Задача 3. Модель стохастической волатильности (BSM + CIR)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

M = 1000  # Количество траекторий
T = 1.0   # Общее время
Nt = 1000 # Количество шагов по времени
dt = T / Nt
t = np.linspace(0, T, Nt + 1)

# Выбираем два непересекающихся интервала
t1, t2 = 0.2, 0.4  # Первый интервал
t3, t4 = 0.6, 0.8  # Второй интервал (не пересекается с первым)

# Индексы для временных интервалов
idx_t1 = int(t1 / dt)
idx_t2 = int(t2 / dt)
idx_t3 = int(t3 / dt)
idx_t4 = int(t4 / dt)

# Массивы для хранения приращений
delta_W1 = np.zeros(M)
delta_W2 = np.zeros(M)

# Генерация M траекторий броуновского движения
np.random.seed(42)  

for i in range(M):
    # Генерируем броуновское движение
    dW = np.random.normal(0, np.sqrt(dt), Nt)
    W = np.cumsum(dW)
    W = np.insert(W, 0, 0)  # W(0) = 0
    
    delta_W1[i] = W[idx_t2] - W[idx_t1]
    delta_W2[i] = W[idx_t4] - W[idx_t3]

# Вычисляем корреляцию между приращениями
correlation, p_value = stats.pearsonr(delta_W1, delta_W2)

print(f"Параметры:")
print(f"Количество траекторий: M = {M}")
print(f"Первый интервал: [{t1}, {t2}]")
print(f"Второй интервал: [{t3}, {t4}]")
print(f"\nРезультаты:")
print(f"Корреляция между ΔW1 и ΔW2: {correlation:.6f}")
print(f"P-value: {p_value:.6f}")
print(f"\nТеоретическая корреляция для непересекающихся интервалов: 0")
print(f"Разница: {abs(correlation):.6f}")

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].scatter(delta_W1, delta_W2, alpha=0.3, s=10, color='blue')
axes[0].set_xlabel('ΔW1 = W(t2) - W(t1)', fontsize=12)
axes[0].set_ylabel('ΔW2 = W(t4) - W(t3)', fontsize=12)
axes[0].set_title(f'Scatter Plot приращений броуновского движения\nКорреляция: {correlation:.4f}', fontsize=12)
axes[0].grid(True, alpha=0.3)
axes[0].axhline(y=0, color='red', linestyle='--', alpha=0.5)
axes[0].axvline(x=0, color='red', linestyle='--', alpha=0.5)

# Гистограммы распределений
axes[1].hist(delta_W1, bins=50, alpha=0.5, label='ΔW1', density=True)
axes[1].hist(delta_W2, bins=50, alpha=0.5, label='ΔW2', density=True)

# Теоретическое нормальное распределение
x = np.linspace(min(min(delta_W1), min(delta_W2)), 
                max(max(delta_W1), max(delta_W2)), 100)
theoretical_std = np.sqrt(t2 - t1)  # Дисперсия приращения броуновского движения
axes[1].plot(x, stats.norm.pdf(x, 0, theoretical_std), 'r--', 
             label='Теоретическое N(0, t2-t1)', linewidth=2)
axes[1].set_xlabel('Значение приращения', fontsize=12)
axes[1].set_ylabel('Плотность вероятности', fontsize=12)
axes[1].set_title('Распределение приращений', fontsize=12)
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Параметры:
# Количество траекторий: M = 1000
# Первый интервал: [0.2, 0.4]
# Второй интервал: [0.6, 0.8]
#
# Результаты:
# Корреляция между ΔW1 и ΔW2: -0.002774
# P-value: 0.930181
#
# Теоретическая корреляция для непересекающихся интервалов: 0
# Разница: 0.002774

# %% [markdown]
# Задача 4. Смена режима для траектории (Regime Switching)

# %%
T1 = 0.5
T2 = 1.0
dt = 0.001
N1 = int(T1 / dt)
N2 = int((T2 - T1) / dt)
N_total = N1 + N2
t1 = np.linspace(0, T1, N1 + 1)
t2 = np.linspace(T1, T2, N2 + 1)
t = np.concatenate((t1, t2[1:]))

# Параметры OU
kappa = 1.0
theta = 1.2
sigma_ou = 0.2
X0_ou = 1.0

# Симуляция OU
X_ou = np.zeros(N1 + 1)
X_ou[0] = X0_ou
dW_ou = np.random.normal(0, np.sqrt(dt), N1)
for i in range(N1):
    dX = kappa * (theta - X_ou[i]) * dt + sigma_ou * dW_ou[i]
    X_ou[i + 1] = X_ou[i] + dX

# Параметры BSM для второй части
mu_bsm = 0.05
sigma_bsm = 0.2
X0_bsm = X_ou[-1] # Начальное состояние для BSM - конец OU

# Симуляция BSM
X_bsm = np.zeros(N2 + 1)
X_bsm[0] = X0_bsm
dW_bsm = np.random.normal(0, np.sqrt(dt), N2)
for i in range(N2):
    dX = mu_bsm * X_bsm[i] * dt + sigma_bsm * X_bsm[i] * dW_bsm[i]
    X_bsm[i + 1] = X_bsm[i] + dX

# Объединение траекторий
X_total = np.concatenate((X_ou, X_bsm[1:]))

plt.figure(figsize=(12, 6))
plt.plot(t, X_total, label='Траектория (OU -> BSM)')
plt.axvline(x=T1, color='r', linestyle='--', label='Смена режима (t=0.5)')
plt.title('Смена режима: OU на [0, 0.5], BSM на [0.5, 1.0]')
plt.xlabel('Время')
plt.ylabel('X(t)')
plt.legend()
plt.grid(True)
plt.show()

# Сохранение в CSV
data_switch = np.column_stack((t, X_total))
np.savetxt('regime_switch_trajectory.csv', data_switch, delimiter=',', header='t,X', comments='')
print("Результаты сохранены в 'regime_switch_trajectory.csv'")
# Out:
# Результаты сохранены в 'regime_switch_trajectory.csv'

# %% [markdown]
# Задача 5. Сравнение моделей с возвратом к среднему

# %%
from scipy.stats import norm, gamma, beta

kappa = 2.0
theta = 1.0
sigma = 0.3
X0 = 1.5
T = 2.0
dt = 0.001
N = int(T / dt)
M = 500
t = np.linspace(0, T, N + 1)

def simulate_ou(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        X[:, i + 1] = X[:, i] + kappa * (theta - X[:, i]) * dt + sigma * dW[:, i]
    return X

def simulate_cir(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        X[:, i + 1] = X[:, i] + kappa * (theta - X[:, i]) * dt + sigma * np.sqrt(np.maximum(X[:, i], 0)) * dW[:, i]
        X[:, i + 1] = np.maximum(X[:, i + 1], 0)
    return X

def simulate_mod_cir(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        X[:, i + 1] = X[:, i] + kappa * (theta - X[:, i]) * dt + sigma * np.abs(X[:, i])**1.5 * dW[:, i]
    return X

def simulate_ait_sahalia(M, N, T, X0, alpha_m1, alpha_0, alpha_1, alpha_2, rho, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        x_safe = np.maximum(np.abs(X[:, i]), 1e-8)
        drift = (alpha_m1 / x_safe + alpha_0 + alpha_1 * X[:, i] + alpha_2 * X[:, i]**2) * dt
        diffusion = sigma * np.abs(X[:, i])**rho * dW[:, i]
        X[:, i + 1] = X[:, i] + drift + diffusion
        X[:, i + 1] = np.maximum(X[:, i + 1], 0)
    return X

def simulate_jacobi(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        x_clipped = np.clip(X[:, i], 0, 1)
        drift = kappa * (theta - X[:, i]) * dt
        diffusion = sigma * np.sqrt(np.maximum(x_clipped * (1 - x_clipped), 0)) * dW[:, i]
        X[:, i + 1] = X[:, i] + drift + diffusion
        X[:, i + 1] = np.clip(X[:, i + 1], 0, 1)
    return X

np.random.seed(42)
X_ou = simulate_ou(M, N, T, X0, kappa, theta, sigma)
X_cir = simulate_cir(M, N, T, X0, kappa, theta, sigma)
X_mod_cir = simulate_mod_cir(M, N, T, X0, kappa, theta, sigma)
X_ait = simulate_ait_sahalia(M, N, T, X0, 0.5, 0.1, -2, 0, 1.5, sigma)
X_jac = simulate_jacobi(M, N, T, 0.5, kappa, 0.5, sigma)

models = {'OU': X_ou, 'CIR': X_cir, 'Mod CIR': X_mod_cir, 'Ait-Sahalia': X_ait, 'Jacobi': X_jac}

all_data = np.concatenate([X.flatten() for X in models.values()])
y_min = np.percentile(all_data, 1)
y_max = np.percentile(all_data, 99) 
y_min = max(0, y_min)  
y_max = max(y_max, 2.0) 

print(f"Общие границы оси Y: [{y_min:.2f}, {y_max:.2f}]")

for name, X in models.items():
    mean_T = np.mean(X[:, -1])
    var_T = np.var(X[:, -1])
    prob_above_2 = np.mean(X[:, -1] > 2.0)
    prob_below_05 = np.mean(X[:, -1] < 0.5)  # ДОБАВЛЕНО
    print(f"{name}: Mean={mean_T:.4f}, Var={var_T:.4f}, P(X>2)={prob_above_2:.4f}, P(X<0.5)={prob_below_05:.4f}")

fig = plt.figure(figsize=(18, 12))

for i, (name, X) in enumerate(models.items()):
    ax = plt.subplot(2, 3, i + 1)
    for j in range(10):
        ax.plot(t, X[j, :], alpha=0.6, linewidth=1)
    ax.axhline(y=theta if name != 'Jacobi' else 0.5, color='red', linestyle='--', 
               linewidth=2, label=f'θ={theta if name != "Jacobi" else 0.5}')
    ax.set_title(f'{name} (10 траекторий)', fontsize=12, fontweight='bold')
    ax.set_xlabel('Время t')
    ax.set_ylabel('X(t)')
    ax.set_ylim(y_min, y_max)  
    ax.legend(loc='upper right')
    ax.grid(True, alpha=0.3)

ax = plt.subplot(2, 3, 6)
colors = ['blue', 'green', 'red', 'purple', 'orange']
for idx, (name, X) in enumerate(models.items()):
    mean_over_time = np.mean(X, axis=0)
    ax.plot(t, mean_over_time, linewidth=2, label=name, color=colors[idx])
ax.axhline(y=theta, color='black', linestyle='--', linewidth=2, label=f'θ={theta}')
ax.set_title('Выборочные средние по времени\nдля всех моделей', fontsize=12, fontweight='bold')
ax.set_xlabel('Время t')
ax.set_ylabel('Среднее X(t)')
ax.set_ylim(y_min, y_max)  
ax.legend(loc='best', fontsize=9)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('task5_all_models.png', dpi=150, bbox_inches='tight')
plt.show()

print("\n1. Область значений процессов:")
print("   - OU: (-∞, +∞) - может принимать отрицательные значения")
print("   - CIR: [0, +∞) - гарантированная положительность")
print("   - Mod CIR: [0, +∞) - с усечением")
print("   - Ait-Sahalia: (0, +∞) - с ограничением снизу")
print("   - Jacobi: [0, 1] - ограничен интервалом")

print("\n2. Вероятности выхода за пороги:")
for name, X in models.items():
    prob_above_2 = np.mean(X[:, -1] > 2.0)
    prob_below_05 = np.mean(X[:, -1] < 0.5)
    print(f"   {name}: P(X>2)={prob_above_2:.4f}, P(X<0.5)={prob_below_05:.4f}")

print("\n3. Скорость возврата к среднему:")
print("   - Все модели с kappa=2.0 показывают быструю сходимость к θ")
print("   - Jacobi ограничен [0,1], поэтому θ=0.5")

print("\n4. 6-й график показывает, как среднее по ансамблю сходится к θ")
print("   - OU и CIR сходятся быстрее всего")
print("   - Ait-Sahalia показывает нелинейную динамику")
# Out:
# Общие границы оси Y: [0.39, 2.00]
# OU: Mean=0.9996, Var=0.0237, P(X>2)=0.0000, P(X<0.5)=0.0000
# CIR: Mean=1.0005, Var=0.0208, P(X>2)=0.0000, P(X<0.5)=0.0000
# Mod CIR: Mean=1.0070, Var=0.0254, P(X>2)=0.0020, P(X<0.5)=0.0000
# Ait-Sahalia: Mean=0.5317, Var=0.0017, P(X>2)=0.0000, P(X<0.5)=0.2160
# Jacobi: Mean=0.4961, Var=0.0052, P(X>2)=0.0000, P(X<0.5)=0.5220
# 1. Область значений процессов:
#    - OU: (-∞, +∞) - может принимать отрицательные значения
#    - CIR: [0, +∞) - гарантированная положительность
#    - Mod CIR: [0, +∞) - с усечением
#    - Ait-Sahalia: (0, +∞) - с ограничением снизу
#    - Jacobi: [0, 1] - ограничен интервалом
#
# 2. Вероятности выхода за пороги:
#    OU: P(X>2)=0.0000, P(X<0.5)=0.0000
#    CIR: P(X>2)=0.0000, P(X<0.5)=0.0000
#    Mod CIR: P(X>2)=0.0020, P(X<0.5)=0.0000
#    Ait-Sahalia: P(X>2)=0.0000, P(X<0.5)=0.2160
#    Jacobi: P(X>2)=0.0000, P(X<0.5)=0.5220
#
# 3. Скорость возврата к среднему:
#    - Все модели с kappa=2.0 показывают быструю сходимость к θ
#    - Jacobi ограничен [0,1], поэтому θ=0.5
#
# 4. 6-й график показывает, как среднее по ансамблю сходится к θ
#    - OU и CIR сходятся быстрее всего
#    - Ait-Sahalia показывает нелинейную динамику

# %%
kappa = 2.0
theta = 1.0
sigma = 0.3
X0 = 1.5
T = 2.0
dt = 0.001
N = int(T / dt)
M = 500
t = np.linspace(0, T, N + 1)

def simulate_ou(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        X[:, i + 1] = X[:, i] + kappa * (theta - X[:, i]) * dt + sigma * dW[:, i]
    return X

def simulate_cir(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        X[:, i + 1] = X[:, i] + kappa * (theta - X[:, i]) * dt + sigma * np.sqrt(np.maximum(X[:, i], 0)) * dW[:, i]
        X[:, i + 1] = np.maximum(X[:, i + 1], 0)
    return X

def simulate_mod_cir(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        X[:, i + 1] = X[:, i] + kappa * (theta - X[:, i]) * dt + sigma * np.abs(X[:, i])**1.5 * dW[:, i]
    return X

def simulate_ait_sahalia(M, N, T, X0, alpha_m1, alpha_0, alpha_1, alpha_2, rho, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        drift = (alpha_m1 / X[:, i] + alpha_0 + alpha_1 * X[:, i] + alpha_2 * X[:, i]**2) * dt
        diffusion = sigma * np.abs(X[:, i])**rho * dW[:, i]
        X[:, i + 1] = X[:, i] + drift + diffusion
        X[:, i + 1] = np.maximum(X[:, i + 1], 0) # Ограничение снизу для стабильности
    return X

def simulate_jacobi(M, N, T, X0, kappa, theta, sigma):
    dt = T / N
    X = np.zeros((M, N + 1))
    X[:, 0] = X0
    dW = np.random.normal(0, np.sqrt(dt), (M, N))
    for i in range(N):
        drift = kappa * (theta - X[:, i]) * dt
        diffusion = sigma * np.sqrt(X[:, i] * (1 - X[:, i])) * dW[:, i]
        X[:, i + 1] = X[:, i] + drift + diffusion
        X[:, i + 1] = np.clip(X[:, i + 1], 0, 1) # Ограничение [0, 1]
    return X

# Симуляция
X_ou = simulate_ou(M, N, T, X0, kappa, theta, sigma)
X_cir = simulate_cir(M, N, T, X0, kappa, theta, sigma)
X_mod_cir = simulate_mod_cir(M, N, T, X0, kappa, theta, sigma)
X_ait = simulate_ait_sahalia(M, N, T, X0, 0.5, 0.1, -2, 0, 1.5, sigma)
X_jac = simulate_jacobi(M, N, T, 0.5, kappa, 0.5, sigma) 

# Анализ
models = {'OU': X_ou, 'CIR': X_cir, 'Mod CIR': X_mod_cir, 'Ait-Sahalia': X_ait, 'Jacobi': X_jac}
print("Задача 5: Статистика в момент T")
for name, X in models.items():
    mean_T = np.mean(X[:, -1])
    var_T = np.var(X[:, -1])
    prob_threshold = np.mean(X[:, -1] > 2.0)
    print(f"{name}: Mean={mean_T:.4f}, Var={var_T:.4f}, P(X>2)={prob_threshold:.4f}")

plt.figure(figsize=(15, 10))
for i, (name, X) in enumerate(models.items()):
    plt.subplot(2, 3, i + 1)
    for j in range(10):
        plt.plot(t, X[j, :], alpha=0.5)
    plt.title(f'{name} (10 траекторий)')
    plt.xlabel('Время')
    plt.ylabel('X(t)')
    plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Задача 5: Статистика в момент T
# OU: Mean=0.9999, Var=0.0215, P(X>2)=0.0000
# CIR: Mean=1.0140, Var=0.0234, P(X>2)=0.0000
# Mod CIR: Mean=1.0197, Var=0.0272, P(X>2)=0.0000
# Ait-Sahalia: Mean=0.5292, Var=0.0019, P(X>2)=0.0000
# Jacobi: Mean=0.5010, Var=0.0058, P(X>2)=0.0000

# %% [markdown]
# Задача 6. 2D Процесс

# %%
T = 10.0
dt = 0.01
N = int(T / dt)
t = np.linspace(0, T, N + 1)

# Начальное условие
X1 = np.zeros(N + 1)
X2 = np.zeros(N + 1)
X1[0] = 0.5
X2[0] = 0.5

# Симуляция 2D процесса
np.random.seed(42)
dW = np.random.normal(0, np.sqrt(dt), N)

for i in range(N):
    r2 = X1[i]**2 + X2[i]**2
    
    # Дрейф
    if r2 > 1:
        mu1 = 1.0
        mu2 = 1.0
    else:
        mu1 = -X1[i]
        mu2 = X2[i]
    
    # Диффузия
    sigma1 = X1[i] / (1 + r2)
    sigma2 = X2[i] / (1 + r2)
    
    X1[i + 1] = X1[i] + mu1 * dt + sigma1 * dW[i]
    X2[i + 1] = X2[i] + mu2 * dt + sigma2 * dW[i]

fig = plt.figure(figsize=(16, 5))

# 1. Траектория на плоскости
ax1 = plt.subplot(1, 3, 1)
ax1.plot(X1, X2, linewidth=1, alpha=0.7)
ax1.plot(X1[0], X2[0], 'go', markersize=10, label='Старт (0.5, 0.5)')
ax1.plot(X1[-1], X2[-1], 'ro', markersize=10, label='Финиш')

theta_circle = np.linspace(0, 2*np.pi, 100)
ax1.plot(np.cos(theta_circle), np.sin(theta_circle), 'k--', linewidth=2, label='Единичная окружность (r=1)')

ax1.plot([0, 1, 1, 0, 0], [0, 0, 1, 1, 0], 'g-', linewidth=1, alpha=0.5, label='[0,1]×[0,1]')

ax1.set_xlabel('X₁')
ax1.set_ylabel('X₂')
ax1.set_title('Траектория 2D процесса на плоскости')
ax1.legend(loc='best')
ax1.grid(True, alpha=0.3)
ax1.set_aspect('equal')
ax1.set_xlim(-2, 3)
ax1.set_ylim(-2, 3)

# 2. Компоненты во времени
ax2 = plt.subplot(1, 3, 2)
ax2.plot(t, X1, 'b-', linewidth=1.5, label='X₁(t)')
ax2.plot(t, X2, 'r-', linewidth=1.5, label='X₂(t)')
ax2.axhline(y=0, color='gray', linestyle='-', alpha=0.3)
ax2.axhline(y=1, color='green', linestyle='--', alpha=0.5, label='Граница r=1')
ax2.axhline(y=-1, color='green', linestyle='--', alpha=0.5)
ax2.set_xlabel('Время t')
ax2.set_ylabel('Значение')
ax2.set_title('Компоненты процесса во времени')
ax2.legend(loc='best')
ax2.grid(True, alpha=0.3)

ax3 = plt.subplot(1, 3, 3)
r = np.sqrt(X1**2 + X2**2)
ax3.plot(t, r, 'purple', linewidth=2)
ax3.axhline(y=1, color='red', linestyle='--', linewidth=2, label='r=1 (граница)')
ax3.fill_between(t, 0, 1, alpha=0.2, color='green', label='Внутри круга (r≤1)')
ax3.fill_between(t, 1, max(r), alpha=0.2, color='orange', label='Снаружи круга (r>1)')
ax3.set_xlabel('Время t')
ax3.set_ylabel('Расстояние r = √(X₁² + X₂²)')
ax3.set_title('Расстояние от начала координат')
ax3.legend(loc='best')
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('task6_2d_process.png', dpi=150, bbox_inches='tight')
plt.show()


print("\n ПОВЕДЕНИЕ ТРАЕКТОРИИ В ОБЛАСТИ [0,1]×[0,1]:")


# Анализ времени внутри/снаружи круга
time_inside = np.sum(r <= 1) / len(r) * 100
time_outside = np.sum(r > 1) / len(r) * 100

print(f"\n1. Время внутри единичного круга (r≤1): {time_inside:.1f}%")
print(f"   Время снаружи единичного круга (r>1): {time_outside:.1f}%")

print("\n2. Механизм дрейфа:")
print("   - ВНУТРИ круга (r²≤1): дрейф = (-X₁, X₂)")
print("     X₁ стремится к 0 (возврат к оси X₂)")
print("     X₂ растёт экспоненциально (отталкивание от оси X₁)")
print("     Траектория закручивается против часовой стрелки")
print()
print("   - СНАРУЖИ круга (r²>1): дрейф = (1, 1)")
print("     Постоянный снос вправо-вверх")
print("      Траектория уходит в область положительных значений")
print()

print("3. Механизм диффузии:")
print(f"   - Коэффициент: σ(X₁,X₂) = 1/(1+X₁²+X₂²) × [[X₁,0],[X₂,0]]")
print(f"   - При r→0: диффузия → 0 (процесс 'замораживается' в начале)")
print(f"   - При r→∞: диффузия → 0 (процесс становится детерминированным)")
print(f"   - Максимальная волатильность при r≈1")

print("\n4. Почему траектория ведёт себя так в [0,1]×[0,1]:")
print("   Начальная точка (0.5, 0.5) находится ВНУТРИ круга (r=0.707<1)")
print("  Дрейф (-X₁, X₂) создаёт вращательное движение")
print("   Диффузия добавляет случайные колебания")
print("   При выходе за r=1 дрейф меняется на (1,1) - уход из области")
print("   Это создаёт 'ловушку' - процесс стремится остаться near r=1")

print("\n5. Статистика траектории:")
print(f"   - Минимальное расстояние: r_min = {np.min(r):.4f}")
print(f"   - Максимальное расстояние: r_max = {np.max(r):.4f}")
print(f"   - Среднее расстояние: r_mean = {np.mean(r):.4f}")
print(f"   - Начальная точка: ({X1[0]:.2f}, {X2[0]:.2f})")
print(f"   - Конечная точка: ({X1[-1]:.2f}, {X2[-1]:.2f})")
print("Внутри круга - вращательное движение с возвратом к осям.")
print("Снаружи круга - детерминированный снос в положительном направлении.")
print("Диффузия затухает как near начала координат, так и на бесконечности.")
# Out:
#  ПОВЕДЕНИЕ ТРАЕКТОРИИ В ОБЛАСТИ [0,1]×[0,1]:
#
# 1. Время внутри единичного круга (r≤1): 16.6%
#    Время снаружи единичного круга (r>1): 83.4%
#
# 2. Механизм дрейфа:
#    - ВНУТРИ круга (r²≤1): дрейф = (-X₁, X₂)
#      X₁ стремится к 0 (возврат к оси X₂)
#      X₂ растёт экспоненциально (отталкивание от оси X₁)
#      Траектория закручивается против часовой стрелки
#
#    - СНАРУЖИ круга (r²>1): дрейф = (1, 1)
#      Постоянный снос вправо-вверх
#       Траектория уходит в область положительных значений
#
# 3. Механизм диффузии:
#    - Коэффициент: σ(X₁,X₂) = 1/(1+X₁²+X₂²) × [[X₁,0],[X₂,0]]
#    - При r→0: диффузия → 0 (процесс 'замораживается' в начале)
#    - При r→∞: диффузия → 0 (процесс становится детерминированным)
#    - Максимальная волатильность при r≈1
#
# 4. Почему траектория ведёт себя так в [0,1]×[0,1]:
#    Начальная точка (0.5, 0.5) находится ВНУТРИ круга (r=0.707<1)
#   Дрейф (-X₁, X₂) создаёт вращательное движение
#    Диффузия добавляет случайные колебания
#    При выходе за r=1 дрейф меняется на (1,1) - уход из области
#    Это создаёт 'ловушку' - процесс стремится остаться near r=1
#
# 5. Статистика траектории:
#    - Минимальное расстояние: r_min = 0.3249
#    - Максимальное расстояние: r_max = 13.1293
#    - Среднее расстояние: r_mean = 6.0401
#    - Начальная точка: (0.50, 0.50)
#    - Конечная точка: (8.59, 9.93)
# Внутри круга - вращательное движение с возвратом к осям.
# Снаружи круга - детерминированный снос в положительном направлении.
# Диффузия затухает как near начала координат, так и на бесконечности.
